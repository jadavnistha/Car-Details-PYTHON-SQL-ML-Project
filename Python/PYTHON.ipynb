# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Trainer1.FTDC\Downloads\Car_details(U).csv")

# %%
data
# Out:
#      vehicle_uid                                 name  year  selling_price  \
# 0     CAR_000001                        Maruti 800 AC  2007        60000.0
# 1     CAR_000002             Maruti Wagon R LXI Minor  2007       135000.0
# 2     CAR_000003                 Hyundai Verna 1.6 SX  2012       600000.0
# 3     CAR_000004               Datsun RediGO T Option  2017       250000.0
# 4     CAR_000005                Honda Amaze VX i-DTEC  2014       450000.0
# ...          ...                                  ...   ...            ...
# 4335  CAR_004336  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014       409999.0
# 4336  CAR_004337           Hyundai i20 Magna 1.4 CRDi  2014       409999.0
# 4337  CAR_004338                  Maruti 800 AC BSIII  2009       110000.0
# 4338  CAR_004339     Hyundai Creta 1.6 CRDi SX Option  2016       865000.0
# 4339  CAR_004340                     Renault KWID RXT  2016            NaN
#
# ...

# %%
data.isnull().any()
# Out:
# vehicle_uid          False
# name                 False
# year                 False
# selling_price         True
# km_driven             True
# fuel                  True
# seller_type          False
# transmission          True
# owner                False
# car_record_id        False
# car_age              False
# price_category        True
# km_category           True
# owner_count           True
# fuel_transmission    False
# brand                False
# price_per_km         False
# is_diesel            False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price        434
# km_driven            434
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
smax=data['selling_price'].max()

# %%
smin=data['selling_price'].min()

# %%
Savg=(smax+smin)/2

# %%
data['selling_price'].fillna(Savg,inplace=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven            434
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count          434
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
#Q2

# %%
data.describe()
# Out:
#               year  selling_price      km_driven  car_record_id      car_age  \
# count  4340.000000   4.340000e+03    3906.000000    4340.000000  4340.000000
# mean   2013.090783   9.027308e+05   66231.222990    2170.500000    11.909217
# std       4.215344   1.311959e+06   47047.819626    1252.994413     4.215344
# min    1992.000000   2.200000e+04       1.000000       1.000000     5.000000
# 25%    2011.000000   2.250000e+05   35000.000000    1085.750000     9.000000
# 50%    2014.000000   4.000000e+05   60000.000000    2170.500000    11.000000
# 75%    2016.000000   7.500000e+05   90000.000000    3255.250000    14.000000
# max    2020.000000   8.900000e+06  806599.000000    4340.000000    33.000000
#
#        owner_count   price_per_km    is_diesel
# count       3906.0    4340.000000  4340.000000
# mean           0.0      88.013984     0.496083
# std            0.0    3801.519948     0.500042
# min            0.0       0.250000     0.000000
# ...

# %%
data["km_driven"].mean()
# Out:
# 66231.22299027137

# %%
data["km_driven"].fillna(data["km_driven"].mean(),inplace=True)

# %%
data["owner_count"].median()
# Out:
# 0.0

# %%
data["owner_count"].fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category          434
# owner_count            0
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
data["km_category"].mode()
# Out:
# 0    Medium
# Name: km_category, dtype: object

# %%
data["km_category"].isnull().sum()
# Out:
# 434

# %%
434/2
# Out:
# 217.0

# %%
data["km_category"].fillna(data["km_category"].mode()[0],limit=217,inplace=True)

# %%
data["km_category"].isnull().sum()
# Out:
# 217

# %%
data["km_category"].fillna("High",inplace=True)

# %%
data["km_category"].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                 435
# seller_type            0
# transmission         434
# owner                  0
# car_record_id          0
# car_age                0
# price_category       434
# km_category            0
# owner_count            0
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
#Q4

# %%
data.head()
# Out:
#   vehicle_uid                      name  year  selling_price  km_driven  \
# 0  CAR_000001             Maruti 800 AC  2007        60000.0    70000.0
# 1  CAR_000002  Maruti Wagon R LXI Minor  2007       135000.0    50000.0
# 2  CAR_000003      Hyundai Verna 1.6 SX  2012       600000.0   100000.0
# 3  CAR_000004    Datsun RediGO T Option  2017       250000.0    46000.0
# 4  CAR_000005     Honda Amaze VX i-DTEC  2014       450000.0   141000.0
#
#      fuel seller_type transmission         owner  car_record_id  car_age  \
# 0  Petrol  Individual       Manual   First Owner              1       18
# 1     NaN  Individual       Manual   First Owner              2       18
# 2  Diesel  Individual       Manual   First Owner              3       13
# 3  Petrol  Individual       Manual   First Owner              4        8
# 4  Diesel  Individual       Manual  Second Owner              5       11
#
#   price_category km_category  owner_count fuel_transmission    brand  \
# ...

# %%
data["transmission"].unique()
# Out:
# array(['Manual', nan, 'Automatic'], dtype=object)

# %%
modeP=data["price_category"].mode()

# %%
data['price_category'].fillna(modeP[0],inplace=True)

# %%
data["transmission"].fillna("Unknown",inplace=True)

# %%
data.isnull().sum()
# Out:
# vehicle_uid            0
# name                   0
# year                   0
# selling_price          0
# km_driven              0
# fuel                 435
# seller_type            0
# transmission           0
# owner                  0
# car_record_id          0
# car_age                0
# price_category         0
# km_category            0
# owner_count            0
# fuel_transmission      0
# brand                  0
# price_per_km           0
# is_diesel              0
# dtype: int64

# %%
#Q5

# %%
data["fuel"].unique()
# Out:
# array(['Petrol', nan, 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
435/5
# Out:
# 87.0

# %%
data["fuel"].fillna("Petrol",limit=87,inplace=True)

# %%
data["fuel"].fillna("Diesel",limit=87,inplace=True)

# %%
data["fuel"].fillna("CNG",limit=87,inplace=True)

# %%
data["fuel"].fillna("LPG",limit=87,inplace=True)

# %%
data["fuel"].fillna("Electric",limit=87,inplace=True)

# %%
data.isnull().any()
# Out:
# vehicle_uid          False
# name                 False
# year                 False
# selling_price        False
# km_driven            False
# fuel                 False
# seller_type          False
# transmission         False
# owner                False
# car_record_id        False
# car_age              False
# price_category       False
# km_category          False
# owner_count          False
# fuel_transmission    False
# brand                False
# price_per_km         False
# is_diesel            False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# vehicle_uid          0
# name                 0
# year                 0
# selling_price        0
# km_driven            0
# fuel                 0
# seller_type          0
# transmission         0
# owner                0
# car_record_id        0
# car_age              0
# price_category       0
# km_category          0
# owner_count          0
# fuel_transmission    0
# brand                0
# price_per_km         0
# is_diesel            0
# dtype: int64

# %%
data.to_csv("cars_Ml.csv",index=False)

# %%
pwd
# Out:
# 'C:\\Users\\Trainer1.FTDC'

# %%
data[["vehicle_uid", "name", "year", "fuel", "seller_type", "transmission", "owner","brand", "car_age"]].to_csv("vehicle_info.csv",index=False)

# %%
cd Downloads
# Out:
# C:\Users\Trainer1.FTDC\Downloads

# %%
data[["vehicle_uid", "selling_price", "km_driven", "price_category",
"km_category"]].to_csv("vehicle_sales.csv",index=False)
